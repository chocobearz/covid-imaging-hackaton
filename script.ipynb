# %%
import pandas as pd
df = pd.read_csv("metadata.csv")

# %%
df
# Out:
#     patientid offset sex   age   finding survival intubated  \
# 0           2      0   M  65.0  COVID-19        Y         N
# 1           2      3   M  65.0  COVID-19        Y         N
# 2           2      5   M  65.0  COVID-19        Y         N
# 3           2      6   M  65.0  COVID-19        Y         N
# 4           4      0   F  52.0  COVID-19      NaN         N
# ..        ...    ...  ..   ...       ...      ...       ...
# 753       389     16   F   NaN      todo        Y       NaN
# 754       390      0   F   NaN      todo      NaN       NaN
# 755       391      1   M   NaN      todo      NaN       NaN
# 756       391      3   M   NaN      todo      NaN       NaN
# 757       392      3   M   NaN      todo        Y       NaN
#
#     intubation_present went_icu in_icu  ...       date  \
# 0                    N        N      N  ...  22-Jan-20
# 1                    N        N      N  ...  25-Jan-20
# 2                    N        N      N  ...  27-Jan-20
# ...
